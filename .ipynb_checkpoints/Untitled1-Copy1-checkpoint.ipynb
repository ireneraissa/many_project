# 261696  091116_203301_474c565b3799a0cb_79323_UMTS_-71....
# 261697  091116_203307_474c565b3799a0cb_79323_UMTS_-67....
# 261698  091116_203425_474c565b3799a0cb_79323_UMTS_-75....
# 261699  091116_203259_474c565b3799a0cb_79323_UMTS_-61....
# 261700  091116_203302_474c565b3799a0cb_79323_UMTS_-77....
# 261701  091116_203432_474c565b3799a0cb_79323_UMTS_-65....
# 261702  091116_203435_474c565b3799a0cb_79323_UMTS_-65....
# 261703  091116_203436_474c565b3799a0cb_79323_UMTS_-53....
# 261704  091116_203433_474c565b3799a0cb_79323_UMTS_-51....
# 261705  101116_134924_6fedf638d47b7dce_79310_UMTS_-77....
# 261706  101116_134927_6fedf638d47b7dce_79310_UMTS_-83....
# 261707  101116_140051_6fedf638d47b7dce_79310_UMTS_-75....
# 261708                                                  0
#
# [261709 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
name = ['-18', '18-25', '25-50', '50+']
data = [5000, 26000, 21400, 12000]

explode=(0, 0.15, 0, 0)
plt.pie(data, explode=explode, labels=name, autopct='%1.1f%%', startangle=90, shadow=True)
plt.axis('equal')
plt.show()

# %%
del signal_csv['id']
del signal_csv['info']

# %%
signal_csv
# Out:
#                    date_log  device_id  sig
# 0       2016-09-30 13:07:17        283  -97
# 1       2016-09-30 13:07:38        283  -97
# 2       2016-09-30 13:07:49        283  -97
# 3       2016-09-30 13:08:09        283  -97
# 4       2016-09-30 13:08:29        283  -97
# 5       2016-09-30 13:08:49        283  -97
# 6       2016-09-30 13:09:09        283  -97
# 7       2016-09-30 13:09:29        283  -97
# 8       2016-09-30 13:09:49        283  -97
# 9       2016-09-30 13:10:09        283  -97
# 10      2016-09-30 13:10:29        283  -97
# 11      2016-09-30 13:10:49        283  -97
# 12      2016-09-30 13:11:09        283  -97
# 13      2016-09-30 13:11:29        283  -97
# 14      2016-09-30 13:11:49        283  -97
# 15      2016-09-30 13:12:09        283  -97
# 16      2016-09-30 13:12:29        283  -87
# 17      2016-09-30 13:12:49        283  -99
# 18      2016-09-30 13:13:09        283  -93
# 19      2016-09-30 13:13:29        283  -93
# 20      2016-09-30 13:13:49        283  -93
# 21      2016-09-30 13:14:09        283  -93
# 22      2016-09-30 13:14:29        283  -93
# 23      2016-09-30 13:14:50        283  -93
# 24      2016-09-30 13:15:10        283  -93
# 25      2016-09-30 13:15:30        283  -93
# 26      2016-09-30 13:15:50        283  -93
# 27      2016-09-30 13:16:10        283  -93
# 28      2016-09-30 13:16:30        283  -93
# 29      2016-09-30 13:16:50        283  -93
# ...                     ...        ...  ...
# 261679  2016-11-09 20:29:58        141  -61
# 261680  2016-11-09 20:30:01        141  -51
# 261681  2016-11-09 20:29:59        141  -55
# 261682  2016-11-09 20:31:20        141  -59
# 261683  2016-11-09 20:31:21        141  -63
# 261684  2016-11-09 20:31:27        141  -69
# 261685  2016-11-09 20:31:25        141  -69
# 261686  2016-11-09 20:31:31        141  -79
# 261687  2016-11-09 20:31:32        141  -69
# 261688  2016-11-09 20:31:22        141  -63
# 261689  2016-11-09 20:31:24        141  -69
# 261690  2016-11-09 20:31:29        141  -63
# %%
date_log=signal_csv['date_log']
del signal_csv['date_log']

# %%
signal_csv
# Out:
#         device_id  sig
# 0             283  -97
# 1             283  -97
# 2             283  -97
# 3             283  -97
# 4             283  -97
# 5             283  -97
# 6             283  -97
# 7             283  -97
# 8             283  -97
# 9             283  -97
# 10            283  -97
# 11            283  -97
# 12            283  -97
# 13            283  -97
# 14            283  -97
# 15            283  -97
# 16            283  -87
# 17            283  -99
# 18            283  -93
# 19            283  -93
# 20            283  -93
# 21            283  -93
# 22            283  -93
# 23            283  -93
# 24            283  -93
# 25            283  -93
# 26            283  -93
# 27            283  -93
# 28            283  -93
# 29            283  -93
# ...           ...  ...
# 261679        141  -61
# 261680        141  -51
# 261681        141  -55
# 261682        141  -59
# 261683        141  -63
# 261684        141  -69
# 261685        141  -69
# 261686        141  -79
# 261687        141  -69
# 261688        141  -63
# 261689        141  -69
# 261690        141  -63
# 261691        141  -81
# 261692        141  -71
# 261693        141  -55
# 261694        141  -77
# 261695        141  -83
# 261696        141  -71
# 261697        141  -67
# 261698        141  -75
# 261699        141  -61
# 261700        141  -77
# 261701        141  -65
# 261702        141  -65
# 261703        141  -53
# 261704        141  -51
# 261705        240  -77
# 261706        240  -83
# 261707        240  -75
# 261708        323  -50
#
# [261709 rows x 2 columns]

# %%
heure_date=pd.DataFrame(list(date_log))
heure_date
# Out:
#                           0
# 0       2016-09-30 13:07:17
# 1       2016-09-30 13:07:38
# 2       2016-09-30 13:07:49
# 3       2016-09-30 13:08:09
# 4       2016-09-30 13:08:29
# 5       2016-09-30 13:08:49
# 6       2016-09-30 13:09:09
# 7       2016-09-30 13:09:29
# 8       2016-09-30 13:09:49
# 9       2016-09-30 13:10:09
# 10      2016-09-30 13:10:29
# 11      2016-09-30 13:10:49
# 12      2016-09-30 13:11:09
# 13      2016-09-30 13:11:29
# 14      2016-09-30 13:11:49
# 15      2016-09-30 13:12:09
# 16      2016-09-30 13:12:29
# 17      2016-09-30 13:12:49
# 18      2016-09-30 13:13:09
# 19      2016-09-30 13:13:29
# 20      2016-09-30 13:13:49
# 21      2016-09-30 13:14:09
# 22      2016-09-30 13:14:29
# 23      2016-09-30 13:14:50
# 24      2016-09-30 13:15:10
# 25      2016-09-30 13:15:30
# 26      2016-09-30 13:15:50
# 27      2016-09-30 13:16:10
# 28      2016-09-30 13:16:30
# 29      2016-09-30 13:16:50
# ...                     ...
# 261679  2016-11-09 20:29:58
# 261680  2016-11-09 20:30:01
# 261681  2016-11-09 20:29:59
# 261682  2016-11-09 20:31:20
# 261683  2016-11-09 20:31:21
# 261684  2016-11-09 20:31:27
# 261685  2016-11-09 20:31:25
# 261686  2016-11-09 20:31:31
# 261687  2016-11-09 20:31:32
# 261688  2016-11-09 20:31:22
# 261689  2016-11-09 20:31:24
# 261690  2016-11-09 20:31:29
# 261691  2016-11-09 20:32:52
# 261692  2016-11-09 20:32:54
# 261693  2016-11-09 20:32:57
# 261694  2016-11-09 20:32:55
# 261695  2016-11-09 20:33:04
# 261696  2016-11-09 20:33:01
# 261697  2016-11-09 20:33:07
# 261705        240  -77  2016-11-10  13:49:24
# 261706        240  -83  2016-11-10  13:49:27
# 261707        240  -75  2016-11-10  14:00:51
# 261708        323  -50  2017-01-10  20:00:00
#
# [261709 rows x 4 columns]

# %%
SIGNAL.loc[[1]]
SIGNAL.values[0]
# Out:
# array([283, -97, '2016-09-30', '13:07:17'], dtype=object)

# %%
ID=[]
for line in SIGNAL['device_id']:
    ID.append(line)
    
ID_device=(list(set(ID))) 
ID_device.sort()

# %%
SIGNAL[SIGNAL.device_id==115]
# Out:
#         device_id  sig         day      hour
# 244883        115   85  2016-12-09  18:32:45
# 244884        115   85  2016-12-09  18:34:59
# 244885        115   85  2016-12-09  18:48:41
# 257970        115   85  2016-12-17  15:29:18
# 259104        115   85  2016-12-17  12:06:53
# 259105        115   85  2016-12-17  12:07:23
# 259106        115   85  2016-12-17  12:07:53
# 259107        115   85  2016-12-17  12:15:13
# 259108        115   85  2016-12-17  12:26:13

# %%
GRoupee=[]
for i in range(len(ID_device)): 
    GRoupee.append(SIGNAL[SIGNAL.device_id==ID_device[i]])

# %%
GRoupee[0]['device_id'].index[0]
# Out:
# 244883

# %%
#GRoupee[0]['device_id'][GRoupee[0]['device_id'].index[0]] == GRoupee[0]['device_id'][GRoupee[0]['device_id'].index[1]]
s=[]
s.append(GRoupee[0].drop(GRoupee[0]['device_id'].index[0], axis=0))
s[0]
# Out:
#         device_id  sig         day      hour
# 257970        115   85  2016-12-17  15:29:18
# 259104        115   85  2016-12-17  12:06:53
# 259105        115   85  2016-12-17  12:07:23
# 259106        115   85  2016-12-17  12:07:53
# 259107        115   85  2016-12-17  12:15:13
# 259108        115   85  2016-12-17  12:26:13

# %%
#range((len(GRoupee[0])))
#(len(GRoupee[0]))-1
a=GRoupee[0][['device_id','sig']].index[0]
GRoupee[0][['device_id','sig']][a]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.5/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2392             try:
# -> 2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20405)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20359)()
#
# KeyError: 244883
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-313-f3fcf7c85f16> in <module>()
#       2 #(len(GRoupee[0]))-1
#       3 a=GRoupee[0][['device_id','sig']].index[0]
# ----> 4 GRoupee[0][['device_id','sig']][a]
#
# /usr/local/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2060             return self._getitem_multilevel(key)
#    2061         else:
# -> 2062             return self._getitem_column(key)
#    2063
#    2064     def _getitem_column(self, key):
#
# /usr/local/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2067         # get column
#    2068         if self.columns.is_unique:
# -> 2069             return self._get_item_cache(key)
#    2070
#    2071         # duplicate columns & possible reduce dimensionality
#
# /usr/local/lib/python3.5/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1532         res = cache.get(item)
#    1533         if res is None:
# -> 1534             values = self._data.get(item)
#    1535             res = self._box_item_values(item, values)
#    1536             cache[item] = res
#
# /usr/local/lib/python3.5/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /usr/local/lib/python3.5/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
# -> 2395                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2396
#    2397         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20405)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20359)()
#
# KeyError: 244883

# %%
#Si=[]
#for j in range((len(GRoupee[0])-1)):
 #       if GRoupee[0]['device_id'][GRoupee[0]['device_id'].index[j]]==GRoupee[0]['device_id'][GRoupee[0]['device_id'].index[j+1]]:
#
 #           Si.append(GRoupee[0]['device_id'].index[j+1])
                  
            #GRoupee[i]['hour'][j]= + GRoupee[i]['hour'][a]
            #AF=GRoupee[0][GRoupee[0].device_id != GRoupee[0]['device_id'][GRoupee[0]['device_id'].index[j+1]]]
#GRoupee[0].drop(Si, axis=0, inplace=True)

# %%
total=[]

for i in range(len(GRoupee)) :
    
    #for j in  range(len(GRoupee[i])):
        #if GRoupee[i]['device_id','sig','day'][j]== GRoupee[i]['device_id','sig','day'][j+1]:
    #counter=sum(GRoupee[i]['device_id','sig','day'][j]== GRoupee[i]['device_id','sig','day'][j+1] )
    lis=[]
    for j in range((len(GRoupee[i]))-1):
        if GRoupee[i]['Sig'][GRoupee[i]['device_id'].index[j]]==GRoupee[i]['Sig'][GRoupee[i]['device_id'].index[j+1]]
             and GRoupee[i]['day'][GRoupee[i]['day'].index[j]]==GRoupee[i]['day'][GRoupee[i]['day'].index[j+1]]:
            
            #print(1)
            lis.append(GRoupee[i]['device_id'].index[j+1])
            #a=len(lis)
            #GRoupee[i]['hour'][j]= + GRoupee[i]['hour'][a]
    total.append(lis)
            #GRoupee[i]['hour'][j]+GRoupee[i]['hour'][counter]
# Out:
#   File "<tokenize>", line 14
#     lis.append(GRoupee[i]['device_id'].index[j+1])
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
SIGNAL_groupe=[]
ordonne=[] 
for j in range((len(SIGNAL))-250000):
    liste=[]
   
    if SIGNAL1.device_id[j]==SIGNAL1.device_id[j+1]  :
        liste.extend((SIGNAL1.device_id[j],SIGNAL1.sig[j],SIGNAL1.day[j],SIGNAL.hour[j])) 
        ordonne.append(liste)
        #max(SIGNAL.device_id[SIGNAL.device_id == 283].index.tolist())
        SIGNAL_groupe.append(ordonne) 
    else:
        lis=[]
        ords=[]
        lis.extend((SIGNAL1.device_id[j],SIGNAL1.sig[j],SIGNAL1.day[j],SIGNAL.hour[j])) 
        ords.append(liste)
        #max(SIGNAL.device_id[SIGNAL.device_id == 283].index.tolist())
        SIGNAL_groupe.append(ords) 
        j=j+1   

SIGNAL_groupe
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
    
#for i in range(len(GRoupee)):
    #ID_device[i] = SIGNAL[SIGNAL.device_id==ID_device[i] ]
    #ID_device[i].drop(ID_device[i].columns[[0]], axis=1, inplace=True)
#del ID_device[0]['device_id']

#pd.DataFrame(GRoupee[0].set_index('device_id').T)

# %%
SIGNAL.loc[[1]]
# Out:
#    device_id  sig         day
# 1        283  -97  2016-09-30

# %%
SIGNAL.loc[[0]]==SIGNAL.loc[[1]]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-98-81de549efc94> in <module>()
# ----> 1 SIGNAL.loc[[0]]==SIGNAL.loc[[1]]
#
# /usr/local/lib/python3.5/site-packages/pandas/core/ops.py in f(self, other)
#    1294     def f(self, other):
#    1295         if isinstance(other, pd.DataFrame):  # Another DataFrame
# -> 1296             return self._compare_frame(other, func, str_rep)
#    1297         elif isinstance(other, ABCSeries):
#    1298             return self._combine_series_infer(other, func)
#
# /usr/local/lib/python3.5/site-packages/pandas/core/frame.py in _compare_frame(self, other, func, str_rep)
#    3668     def _compare_frame(self, other, func, str_rep):
#    3669         if not self._indexed_same(other):
# -> 3670             raise ValueError('Can only compare identically-labeled '
#    3671                              'DataFrame objects')
#    3672         return self._compare_frame_evaluate(other, func, str_rep)
#
# ValueError: Can only compare identically-labeled DataFrame objects
