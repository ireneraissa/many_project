# %% [markdown]
#  ### Python as a toolbox

# %%
import urllib
import requests

# %%
import urllib.request
from  urllib.request import urlopen

# %%
urlopen("http://www.python.org/").read()
# Out:
# b'<!doctype html>\n<!--[if lt IE 7]>   <html class="no-js ie6 lt-ie7 lt-ie8 lt-ie9">   <![endif]-->\n<!--[if IE 7]>      <html class="no-js ie7 lt-ie8 lt-ie9">          <![endif]-->\n<!--[if IE 8]>      <html class="no-js ie8 lt-ie9">                 <![endif]-->\n<!--[if gt IE 8]><!--><html class="no-js" lang="en" dir="ltr">  <!--<![endif]-->\n\n<head>\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n\n    <link rel="prefetch" href="//ajax.googleapis.com/ajax/libs/jquery/1.8.2/jquery.min.js">\n\n    <meta name="application-name" content="Python.org">\n    <meta name="msapplication-tooltip" content="The official home of the Python Programming Language">\n    <meta name="apple-mobile-web-app-title" content="Python.org">\n    <meta name="apple-mobile-web-app-capable" content="yes">\n    <meta name="apple-mobile-web-app-status-bar-style" content="black">\n\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\n    <meta name="
# ...

# %% [markdown]
# # Act 1: Web scraping

# %%
#Installing dependencies
#sudo pip install BeautifulSoup
#sudo pip install Requests

# %% [markdown]
# ## Analyzing the HTML

# %% [markdown]
# HTML is the framework that, in most cases, contains the content of a page.
#
# But unless you’ve got something fancy on your hands, the data you’re seeking to scrape is usually somewhere within the HTML of the page and your job is to write a script in just the write way to walk through it and pull out the data. In this case, we’ll be looking to extract data from the big table that makes up the heart of the page.
#
# By the time we’re finished, we want to have extracted that data, now encrusted in layers of HTML, into a clean spreadsheet.
# #### There are many ways to grab content from HTML, and every page you scrape data from will require a slightly different trick.
# In the best cases, you can extract content by using the id or class already assigned to the element you’d like to extract. An ‘id’ is intended to act as the unique identifer a specific item on a page. A ‘class’ is used to label a specific type of item on a page. So, there maybe may instances of a class on a page.

# %% [markdown]
# ### Extracting an HTML table

# %%
# i am not able to import request 'import Request'
#import request

# %%
url = 'http://www.showmeboone.com/sheriff/JailResidents/JailResidents.asp'
response = urllib.request.urlopen(url).read()#  when you use request , here is requests.get(url), 
#and so you can use html = response.content
html=response
print(html)
# Out:
# b'<!DOCTYPE html>\n<html>\n    <head>        <title>Current Detainees of Boone County Jail</title>\n        <meta content="IE=edge" http-equiv="X-UA-Compatible" />\n        <meta content="width=device-width, initial-scale=1.0" name="viewport" />\n<!--  -->\n<!-- MultipleRecordApp: CURRENT DETAINEES. Created: Thu Apr 06 13:51:13 CDT 2017 by ITBRANDO. INQHTM-MUL 20120709 -->\n        <link href="/mrcjava/mrcclasses/SH01_MP/favicon.ico" rel="shortcut icon" />\n        <link href="/mrcjava/mrcclasses/mrc_servlet_ajax.css" rel="stylesheet" type="text/css" />\n        <link href="/mrcjava/mrcclasses/SH01_MP/mrc_default.css?v=0.74" mrcfile="150" rel="stylesheet" type="text/css" />\n        <link href="/mrcjava/mrcclasses/jquery.custom.css" rel="stylesheet" type="text/css" />\n<!--[if !IE]>\n<link href="/mrcjava/mrcclasses/mrc-responsive.css" rel="stylesheet" />\n<![endif]-->\n<!--[if IE 7]>\n<link href="/mrcjava/mrcclasses/font/css/font-awesome-ie7.css" rel="stylesheet" />\n<![endif]-->\n  
# ...

# %%
ls
# Out:
# apprentissage_webscraping.ipynb     scrap.ipynb
# chromedriver                        Untitled15.ipynb
# chromedriver_linux32.zip            Untitled18.ipynb
# ghostdriver.log                     Untitled19.ipynb
# inmates1.csv                        Untitled1.ipynb
# inmates.csv                         Untitled2.ipynb
# Non confirmé 72708.crdownload       Untitled3.ipynb
# ouvrir_un_fichier_sur_python.ipynb  Untitled.ipynb
# primitif_de_python.ipynb

# %%
pwd
# Out:
# '/home/irene/Documents/programme'

# %% [markdown]
# Next we take all the detective work we did with the page’s HTML above and convert it into a
# simple, direct command that will instruct BeautifulSoup on how to extract only the table we’re after.

# %%
import requests #enfin request a import, erreur faite j'avais pas mis s

# %%
from bs4 import BeautifulSoup

url = 'http://www.showmeboone.com/sheriff/JailResidents/JailResidents.asp'
response = requests.get(url)
html = response.content

soup = BeautifulSoup(html)
print(soup.prettify() )
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Current Detainees of Boone County Jail
#   </title>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <!-- -->
#   <!-- MultipleRecordApp: CURRENT DETAINEES. Created: Thu Apr 06 13:51:13 CDT 2017 by ITBRANDO. INQHTM-MUL 20120709 -->
#   <link href="/mrcjava/mrcclasses/SH01_MP/favicon.ico" rel="shortcut icon"/>
#   <link href="/mrcjava/mrcclasses/mrc_servlet_ajax.css" rel="stylesheet" type="text/css"/>
#   <link href="/mrcjava/mrcclasses/SH01_MP/mrc_default.css?v=0.74" mrcfile="150" rel="stylesheet" type="text/css"/>
#   <link href="/mrcjava/mrcclasses/jquery.custom.css" rel="stylesheet" type="text/css"/>
#   <!--[if !IE]>
# <link href="/mrcjava/mrcclasses/mrc-responsive.css" rel="stylesheet" />
# <![endif]-->
#   <!--[if IE 7]>
# <link href="/mrcjava/mrcclasses/font/css/font-awesome-ie7.css" rel="stylesheet" />
# <![endif]-->
# ...

# %% [markdown]
# Next we take all the detective work we did with the page’s HTML above and convert
# it into a simple, direct command that will instruct BeautifulSoup on how to extract only the table we’re after.

# %%
pwd
# Out:
# '/home/irene/Documents/programme'

# %%
url = 'http://www.showmeboone.com/sheriff/JailResidents/JailResidents.asp'
response = requests.get(url)
html = response.content

soup = BeautifulSoup(html)
table = soup.find('tbody', attrs={'class': 'stripe'})
print(table.prettify())
# Out:
# <tbody class="stripe" id="mrc_main_table">
#  <!-- -->
#  <tr class="odd">
#   <td class="one td_left" data-th="Last Name">
#    ADAMS
#   </td>
#   <td class="one td_left" data-th="First Name">
#    JEREMIAH
#   </td>
#   <td class="one td_left" data-th="Middle Name">
#    SETH
#   </td>
#   <td class="one td_left" data-th="Sex">
#    M
#   </td>
#   <td class="one td_left" data-th="Race">
#    W
#   </td>
#   <td class="one td_right" data-th="Age">
#    42
#   </td>
#   <td class="one td_left" data-th="City">
#    CENTRALIA
#   </td>
#   <td class="one td_left" data-th="State">
#    MO
#   </td>
#   <td class="one td_left" data-th="">
#    <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=23883&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#     <i class="fa fa-large fa-fw fa-list-alt">
#     </i>
#     Details
#    </a>
#   </td>
#  </tr>
#  <!-- -->
#  <tr class="even">
# ...

# %% [markdown]
# Now that we have our hands on the table, we need to convert the rows in the table into a list,
# which we can then loop through and grab all the data out of.
# BeautifulSoup gets us going by allowing us to dig down into our table and return a list of rows,
# which are created in HTML using < tr > tags inside the table.

# %%
url ='http://www.showmeboone.com/sheriff/JailResidents/JailResidents.asp'
response = requests.get(url)
html = response.content

# %% [markdown]
# la boucle ci-dessus de ressortir les commandes dans tbody ,et de ne prendre que ceux qui sont entre la balise tr

# %%
soup = BeautifulSoup(html)
table = soup.find('tbody', attrs={'class': 'stripe'})
for line in table.findAll('tr'):
    print (line.prettify())
# Out:
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   ADAMS
#  </td>
#  <td class="one td_left" data-th="First Name">
#   JEREMIAH
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   SETH
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   42
#  </td>
#  <td class="one td_left" data-th="City">
#   CENTRALIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=23883&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   ALEXANDER
#  </td>
#  <td class="two td_left" data-th="First Name">
# ...

# %% [markdown]
# Next we can loop through each of the cells in each row by select them inside the loop. Cells
# are created in HTML by the < td > tag.

# %%
for row in table.findAll('tr'):
    for cell in row.findAll('td'):
        print (cell.text)
# Out:
# ADAMS
# JEREMIAH
# SETH
# M
# W
# 42
# CENTRALIA
# MO
#
#  Details
#
# ALEXANDER
# JOHN
# ROSS
# M
# W
# 33
# HALLSVILLE
# MO
#
#  Details
#
# ANDERSON
# RICHARD
# KENNETH
# M
# B
# 23
# COLUMBIA
# MO
#
#  Details
#
# ARRANT
# WILLIAM
# MADISON
# M
# W
# 44
# CANTONMENT
# FL
#
#  Details
#
# ARTEAGA
# BRAYAN
# OSIRIS-CACHO
# M
# H
# 25
# JEFFERSON CITY
# MO
#
#  Details
#
# AVALOS-AVALOS
# JOSE
#
# M
# H
# 19
# ST.ANN
# MO
#
#  Details
#
# BANKS
# MAURICE
# LAMARR
# M
# B
# 25
# COLUMBIA
# MO
#
#  Details
#
# BARNES
# DARIN
# WAYNE
# M
# W
# 32
# HIGBEE
# MO
#
#  Details
#
# BARRETT
# NICHOLE
# RAYSHEA
# F
# B
# 32
# COLUMBIA
# MO
#
#  Details
#
# BARTZ-OWENS
# ASHLEY
# SUE
# F
# W
# 31
# COLUMBIA
# MO
#
#  Details
#
# BENNETT
# EMAS
# CASSELL
# M
# B
# 38
# KANSAS CITY
# MO
#
#  Details
#
# BENNETT
# ROBERT
# DAVID
# M
# B
# 38
# COLUMBIA
# MO
#
#  Details
#
# BERARDI
# DEBORAH
# EVA
# F
# W
# 55
# COLUMBIA
# MO
#
#  Details
#
# BLAIR
# RYAN
# WADE
# M
# W
# 25
# MEXICO
# MO
#
# ...

# %% [markdown]
# When that prints you will notice some annoying "&nbsp"; on the end of many lines. That is the HTML code for a non-breaking space, which forces the browser to render an empty space on the page. It is junk and we can delete it easily with this handy Python trick.

# %% [markdown]
# Now that we have found the data we want to extract, we need to structure it in a way that can be written out to a
# comma-delimited text file. That won’t be hard since CSVs aren’t anymore than a grid of columns and rows, much like a table.

# %%
for row in table.findAll('tr'):
    list_of_cells = []
    for cell in row.findAll('td'):
        text = cell.text.replace('B', 'Black') # cell.text.replace('W', 'white')
      
        #list_of_cells.append(text)
        list_of_cells.append(text)
    for cell in row.findAll('td'):
        tex=cell.text.replace('W', 'white')
        list_of_cells.append(tex)
        print (list_of_cells)
# Out:
# ['ADAMS', 'JEREMIAH', 'SETH', 'M', 'W', '42', 'CENTRALIA', 'MO', '\n\xa0Details\n', 'ADAMS']
# ['ADAMS', 'JEREMIAH', 'SETH', 'M', 'W', '42', 'CENTRALIA', 'MO', '\n\xa0Details\n', 'ADAMS', 'JEREMIAH']
# ['ADAMS', 'JEREMIAH', 'SETH', 'M', 'W', '42', 'CENTRALIA', 'MO', '\n\xa0Details\n', 'ADAMS', 'JEREMIAH', 'SETH']
# ['ADAMS', 'JEREMIAH', 'SETH', 'M', 'W', '42', 'CENTRALIA', 'MO', '\n\xa0Details\n', 'ADAMS', 'JEREMIAH', 'SETH', 'M']
# ['ADAMS', 'JEREMIAH', 'SETH', 'M', 'W', '42', 'CENTRALIA', 'MO', '\n\xa0Details\n', 'ADAMS', 'JEREMIAH', 'SETH', 'M', 'white']
# ['ADAMS', 'JEREMIAH', 'SETH', 'M', 'W', '42', 'CENTRALIA', 'MO', '\n\xa0Details\n', 'ADAMS', 'JEREMIAH', 'SETH', 'M', 'white', '42']
# ['ADAMS', 'JEREMIAH', 'SETH', 'M', 'W', '42', 'CENTRALIA', 'MO', '\n\xa0Details\n', 'ADAMS', 'JEREMIAH', 'SETH', 'M', 'white', '42', 'CENTRALIA']
# ...

# %%
list_of_rows = [] 
for row in table.findAll('tr'):
    list_of_cells = []
    for cell in row.findAll('td'):
        text = cell.text.replace('&nbsp;', '')
        text = cell.text.replace('\n\xa0Details\n', '')
        list_of_cells.append(text)
        list_of_rows.append(list_of_cells)
print (list_of_rows)
# Out:
# [['ADAMS', 'JEREMIAH', 'SETH', 'M', 'W', '42', 'CENTRALIA', 'MO', ''], ['ADAMS', 'JEREMIAH', 'SETH', 'M', 'W', '42', 'CENTRALIA', 'MO', ''], ['ADAMS', 'JEREMIAH', 'SETH', 'M', 'W', '42', 'CENTRALIA', 'MO', ''], ['ADAMS', 'JEREMIAH', 'SETH', 'M', 'W', '42', 'CENTRALIA', 'MO', ''], ['ADAMS', 'JEREMIAH', 'SETH', 'M', 'W', '42', 'CENTRALIA', 'MO', ''], ['ADAMS', 'JEREMIAH', 'SETH', 'M', 'W', '42', 'CENTRALIA', 'MO', ''], ['ADAMS', 'JEREMIAH', 'SETH', 'M', 'W', '42', 'CENTRALIA', 'MO', ''], ['ADAMS', 'JEREMIAH', 'SETH', 'M', 'W', '42', 'CENTRALIA', 'MO', ''], ['ADAMS', 'JEREMIAH', 'SETH', 'M', 'W', '42', 'CENTRALIA', 'MO', ''], ['ALEXANDER', 'JOHN', 'ROSS', 'M', 'W', '33', 'HALLSVILLE', 'MO', ''], ['ALEXANDER', 'JOHN', 'ROSS', 'M', 'W', '33', 'HALLSVILLE', 'MO', ''], ['ALEXANDER', 'JOHN', 'ROSS', 'M', 'W', '33', 'HALLSVILLE', 'MO', ''], ['ALEXANDER', 'JOHN', 'ROSS', 'M', 'W', '33', 'HALLSVILLE', 'MO', ''], ['ALEXANDER', 'JOHN', 'ROSS', 'M', 'W', '33', 'HALLSVILLE', 'MO', ''], ['ALEXANDER'
# ...

# %%
type(list_of_rows)
# Out:
# list

# %%
import csv

# %%
outfile = open("./inmates.csv", "w")
writer = csv.writer(outfile)

# %%
writer.writerow(["Last", "First", "Middle", "Gender", "Race", "Age", "City", "State"])
writer.writerows(list_of_rows)

# %%
#https://first-web-scraper.readthedocs.io/en/latest/#installing-dependencies,
#http://www.xavierdupre.fr/app/ensae_teaching_cs/helpsphinx2/notebooks/TD2A_Eco_Web_Scraping_enonce.html

# %% [markdown]
# # samedi 12-05-2017
#
# savoir pourquoi une puce a ccommence que les autres et savoir si les puces sont active
# trouve un moyen de tester cette fonctionnalite
# qualifier la donnee geolocalisation,
# diagnostic
# sur quoi je dois travailler =la qualite du reseau,
# 1- savoir combien de temps le device est connecte
# afin
# pouquoi on perd la la connectivite ou pourquoi est ce que on la retrouve .Trouver une solution a ca

# %%
soup.find_all('img')
# Out:
# [<img alt="Boone County Sheriff's Badge" src="/mrcjava/mrcclasses/SH01_MP/BCSD-title2.jpg"/>,
#  <img alt="Boone County Sheriff's Badge" class="bcSeal shBadge" src="/mrcjava/mrcclasses/SH01_MP/BCSD-title2.jpg"/>,
#  <img alt="" height="19" onclick="saveView();" src="/mrcjava/image/view_save.png" style="CURSOR: pointer" width="20"/>,
#  <img src="/mrcjava/image/check.png"/>]

# %%
a=soup.find('tbody', {'class' : 'stripe'})

b=a.find_all('a')
for cell in b:
    print(cell.text)
#a.find_element_by_css_selector(cell.text).click()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-676a630d6d47> in <module>()
# ----> 1 a=soup.find('tbody', {'class' : 'stripe'})
#       2
#       3 b=a.find_all('a')
#       4 for cell in b:
#       5     print(cell.text)
#
# NameError: name 'soup' is not defined

# %%
find_e
# Out:
# []

# %%
table_div = table.find('document' , {'id': "infoContainer" })
table_div

# %%
#for urlimg in
soup.find_all("body")
  #  dlurl = repr(urlimg)  #convertir la variable spéciale en string
 
    #print(dlurl)
# Out:
# [<body>
#  <!-- Begin mrc Header -->
#  <div class="page-wrap">
#  <!-- -->
#  <!-- Begin mrc Default Desktop Header -->
#  <!-- Begin JavaScript Required Message -->
#  <noscript>
#  <div class="warning noJS">
#  		The Boone County website <strong>requires</strong> JavaScript to function correctly. Please enable JavaScript in your browser.
#  	</div>
#  </noscript>
#  <!-- End JavaScript Required Message -->
#  <!-- Begin Image Bar -->
#  <div class="pageHeader DepartmentHeader container">
#  <div class="DepartmentHeaderGraphic">
#  <img alt="Boone County Sheriff's Badge" src="/mrcjava/mrcclasses/SH01_MP/BCSD-title2.jpg"/>
#  </div>
#  <div class="DepartmentHeaderInfo">
#  <div class="DepartmentHeaderTitle">
#        Boone County Sheriff's Department
#      </div>
#  <div class="container">
#  <div class="DepartmentHeaderAddress">
#          Boone County Sheriff's Department<br/>
#          2121 County Dr.<br/>
#          Columbia, MO 65202
#        </div>
# ...

# %%
url = 'http://www.showmeboone.com/sheriff/JailResidents/JailResidents.asp'
r = requests.get(url)
data = r.text
soup = BeautifulSoup(data,'html5lib')
link_set = set()
for link in soup.findAll("a"):
    href = link.get('href')
    if href == None:
        continue
    elif "SH01_MP.I00500s?PERKEP=23883&amp;hover_redir=&amp;height=600&amp;width=950" in href:
        link_set.add(href)    
for link in link_set:
    print (link)

# %%
ali=[]
for href in soup.find("a"):
    ali.append(href.name)

# %%
type(href)
# Out:
# bs4.element.Tag

# %%
ali
# Out:
# [None]

# %%
href.name

# %%
raissa =[]
for line in soup.findAll("a"):
    if line['href']== ' ':
        continue
    else: 
        raissa.append(line['href'])

# %%
 raissa[1:24]
# Out:
# ['/mrcjava/servlet/SH01_MP.I00040s',
#  '/mrcjava/servlet/SH01_MP.I00030s',
#  'http://www.boonecountymo.org/Sheriff/',
#  '/mrcjava/servlet/SH01_MP.I00040s',
#  '/mrcjava/servlet/SH01_MP.I00030s',
#  'http://www.boonecountymo.org/Sheriff/',
#  '#',
#  '#',
#  'SH01_MP.R00250s?run=2',
#  'javascript:void(0)',
#  'javascript:void(0)',
#  '#',
#  'javascript:void(0)',
#  'javascript:void(0)',
#  'javascript:void(0)',
#  'javascript:void(0)',
#  'javascript:void(0)',
#  'javascript:void(0)',
#  'javascript:void(0)',
#  'javascript:void(0)',
#  'javascript:void(0)',
#  'javascript:void(0)',
#  '/mrcjava/mrcclasses/filter_relationship_help.html']

# %%
iren = soup.find('tbody', attrs={'class': 'stripe'})
for line in iren.findAll('tr'):
    print (line.prettify())
# Out:
# <tr class="odd">
#  <td class="one td_left" data-th="Last Name">
#   ADAMS
#  </td>
#  <td class="one td_left" data-th="First Name">
#   JEREMIAH
#  </td>
#  <td class="one td_left" data-th="Middle Name">
#   SETH
#  </td>
#  <td class="one td_left" data-th="Sex">
#   M
#  </td>
#  <td class="one td_left" data-th="Race">
#   W
#  </td>
#  <td class="one td_right" data-th="Age">
#   42
#  </td>
#  <td class="one td_left" data-th="City">
#   CENTRALIA
#  </td>
#  <td class="one td_left" data-th="State">
#   MO
#  </td>
#  <td class="one td_left" data-th="">
#   <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=23883&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#    <i class="fa fa-large fa-fw fa-list-alt">
#    </i>
#    Details
#   </a>
#  </td>
# </tr>
#
# <tr class="even">
#  <td class="two td_left" data-th="Last Name">
#   ALEXANDER
#  </td>
#  <td class="two td_left" data-th="First Name">
# ...

# %%
for line in iren.findAll('a'):
    print (line.prettify())
# Out:
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=23883&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#  <i class="fa fa-large fa-fw fa-list-alt">
#  </i>
#  Details
# </a>
#
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=34564&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#  <i class="fa fa-large fa-fw fa-list-alt">
#  </i>
#  Details
# </a>
#
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=66544&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
#  <i class="fa fa-large fa-fw fa-list-alt">
#  </i>
#  Details
# </a>
#
# <a class="_lookup btn btn-primary" height="600" href="SH01_MP.I00500s?PERKEP=78883&amp;hover_redir=&amp;height=600&amp;width=950" linkedtype="I" mrc="returndata" target="_lookup" width="860">
# ...

# %%
#je vais dans href parce que c'est la que se trouve le lien associe a l'info
raissa =[]
for line in iren.findAll("a"):
    if line['href']== ' ':
        continue
    else: 
        raissa.append(line['href'])

# %%
len(raissa)
# Out:
# 55

# %%
ousmane=raissa[50:55]
ousmane
# Out:
# ['javascript:void(0)',
#  'javascript:void(0)',
#  '#',
#  'javascript:void(0)',
#  'javascript:void(0)']

# %%
#recupere rien que les url dont j'ai besoin
hi=raissa[0:50]

# %%
#c'etait juste pour  voir ce qu'il ya dans le lien demande
for line in hi:
    line
# Out:
# 'SH01_MP.I00500s?PERKEP=34564&hover_redir=&height=600&width=950'

# %%
# vous m'excuseriez pour les notations , j'etais en pleine confusion dans la recherche 
replace=[]
for line in hi:
    replace.append(line.replace(line,'https://report.boonecountymo.org/mrcjava/servlet/'+line))

# %%
#c'est pas important
rayonnant=[]
rei=[]
for line in replace[1:2] :
    re=requests.get(line)
    for line in re:
        rei.append(re.content)
for line in rei:
    rayonnant.append(BeautifulSoup(line,'html5lib'))

# %%
type(rayonnant)
# Out:
# list
